# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\Mark\Desktop\MXH\finalProject\alternative-fuel-locations.csv',usecols=['Fuel Type Code','City'])
df = df.dropna(how='any',axis=0) 
df = df.drop_duplicates()
df
# Out:
#     Fuel Type Code            City
# 0              LPG         Elkhorn
# 1              LPG          DeKalb
# 2              LPG        Hillside
# 3              CNG     Des Plaines
# 4              LPG    Schererville
# ..             ...             ...
# 817           ELEC        Lakemoor
# 823           ELEC       Shorewood
# 826            E85       East Troy
# 839           ELEC  Rolling Meadow
# 853           ELEC  Evergreen Park
#
# [365 rows x 2 columns]

# %% [markdown]
# ## Đồ thị 2 phía

# %%
# Số node và số cạnh
import networkx as nx 
from networkx.algorithms import bipartite
B = nx.Graph()
Fuel_Type_Code = df['Fuel Type Code']
City= df['City']
print("số loại nhiên liệu ",Fuel_Type_Code .nunique())
print("số thành phố",City.nunique())
print("số cạnh ",len(df))
# Out:
# số loại nhiên liệu  6
# số thành phố 218
# số cạnh  365

# %%
# Thêm node vào đồ thị B
for index, row in df.iterrows():
      B.add_edge(row['Fuel Type Code'], row['City'],weight=1)
B.add_nodes_from(City,bipartite =0)
B.add_nodes_from(Fuel_Type_Code,bipartite =1)

# %%
# Chuyển đổi dataframe thành đồ thị,vẽ đồ thị 2 phía
import matplotlib.pyplot as plt
plt.figure(figsize=(12,12))
pos = nx.spring_layout(B)
fig, ax = plt.subplots(1,1, figsize=(8,8), dpi=150)
nx.draw_networkx(B, pos = nx.drawing.layout.bipartite_layout(B,Fuel_Type_Code ),font_size=8,width= 0.4)

# %% [markdown]
# ## Đồ thị 1 phía

# %%
# Đồ thị 1 phía
G = bipartite.weighted_projected_graph(B,City)
plt.figure(figsize=(12, 12))

layout = nx.spring_layout(G)

nx.draw_networkx_nodes(G,
                        layout,
                       nodelist=City,
                       node_size=150,
                       node_color='blue')
nx.draw_networkx_edges(G, layout, edge_color="#cccccc")
node_labels = dict(zip(City,City))
nx.draw_networkx_labels(G, layout, labels=node_labels)
plt.axis('off')

plt.title("Graph Team")

plt.show()

# %%
# Xuất dữ liệu đồ thị 1 phía ra file csv để thực hiện trên Gephi
lables = nx.get_edge_attributes(G,'weight')

# %%
df2 = pd.DataFrame(columns=['source','target','weight'])

# %%
for key, value in lables.items():
  df2=df2.append({'source':key[0],'target':key[1],'weight':value}, ignore_index=True)

# %%
df2.to_csv (r'C:\Users\Mark\Desktop\MXH\finalProject\Excel\data1.csv',index = False, header=True)

# %% [markdown]
# ## Thuật toán Louvain

# %%
#Thuật toán phát hiện cộng đồng Louvain
import matplotlib.cm as cm
import matplotlib
import community.community_louvain as community_louvain
plt.figure(figsize=(17, 12))
partition = community_louvain.best_partition(G)
pos = nx.spring_layout(G)
cmap= cm.get_cmap('viridis', max(partition.values()) +1)
nx.draw_networkx_nodes(G, pos,partition.keys(), node_size=150,
                       cmap=cmap, node_color=list(partition.values()))
nx.draw_networkx_edges(G, pos, alpha=0.5)
nx.draw_networkx_labels(G, pos)
plt.show()

# %%
# Đếm số cụm
import numpy as np
values= list(partition.values())
print('Number of communities: ',len(np.unique(values)))
# Out:
# Number of communities:  3

# %%
#In số node trong các cụm
for i in range(len(np.unique(values))):
  print("nhom",i ,"***********")
  for name,  k in partition.items():
    if k == i:
          print(name)
    print("")
# Out:
# nhom 0 ***********
# Elkhorn
#
# DeKalb
#
# Hillside
#
# Des Plaines
#
# Schererville
#
# Evanston
#
# Markham
#
# Chicago
#
# Cicero
#
# Braidwood
#
#
# Lake Villa
#
#
# De Motte
#
#
#
#
#
#
# Lombard
#
#
#
# Aurora
#
#
#
#
#
#
#
# Valparaiso
#
#
#
#
#
#
#
# Crystal Lake
#
#
#
#
#
#
# Homewood
#
#
# West Chicago
#
#
#
#
#
#
#
#
# Kenosha
#
#
#
#
#
#
#
#
#
#
#
# Naperville
#
#
# Lake Station
#
# Stickney
#
# Lansing
#
# Palatine
#
#
#
# Crestwood
#
#
#
# Bradley
#
#
# Elgin
#
#
#
#
# Round Lake Park
#
#
#
#
#
# Joliet
#
#
#
# Melrose Park
#
#
#
#
#
#
#
#
#
#
#
#
#
# Antioch
#
# Bridgeview
#
#
# Dolton
#
#
# Freeport
#
# Hodgkins
#
# Morris
#
#
# Westmont
#
#
#
#
#
#
#
#
#
#
#
# Gary
#
# Bolingbrook
#
# Hanover Park
#
#
#
#
# Hammond
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Rockdale
#
#
#
#
#
#
#
#
#
#
#
# Hebron
#
#
#
#
#
#
# McCook
#
#
# Park Forest
#
# Morton Grove
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Schriller Park
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nhom 1 ***********
#
#
#
#
#
#
#
#
#
#
# Kankakee
#
#
# Rensselaer
#
#
# Woodstock
#
# Downers Grove
#
# Lemont
#
# Batavia
#
# Great Lakes
#
#
# Oswego
#
# Romeoville
#
#
# Homer Glen
#
# Schaumburg
#
# Riverside
#
# North Aurora
#
# Highland
#
# Merrillville
#
#
# Hobart
#
# Wheatfield
#
# Skokie
#
# Kouts
#
# Portage
#
# Chesterton
#
#
# Crown Point
#
# Remington
#
# Sturtevant
#
# Gages Lake
#
# Roselawn
#
#
#
#
# East Dundee
#
# Lisle
#
# Elmhurst
#
# Lawrence
#
#
# University Park
#
# Robbins
#
#
# Volo
#
#
# Racine
#
# Wood Dale
#
# Palos Hills
#
# Lakemoor
#
# Darien
#
# Lockport
#
# Lowell
#
#
#
# Schiller Park
#
#
#
#
#
# Bloomingdale
#
#
#
#
# Arlington Heights
#
#
#
#
#
#
# St. Charles
#
#
# Elk Grove Village
#
# South Holland
#
#
#
#
#
#
#
#
#
# Orland Park
#
# Fair Oaks
#
#
# Mokena
#
# Country Club Hills
#
# Addison
#
# Park Ridge
#
#
# Villa Park
#
#
#
#
# Crest Hill
#
#
# Fox Lake
#
#
#
#
# Plainfield
#
#
# Yorkville
#
# Highland Park
#
# Evergreen Park
#
# Burlington
#
# Cary
#
# Island Lake
#
# Oak lawn
#
# Third Lake
#
# Woodridge
#
#
#
#
#
#
# North Chicago
#
#
#
#
#
# Forest Park
#
# Alsip
#
# Willowbrook
#
# West Dundee
#
#
#
# Crete
#
#
# New Lenox
#
# Buffalo Grove
#
#
#
# Burbank
#
# Bensenville
#
#
#
#
#
#
# Kildeer
#
# East Chicago
#
#
# Montgomery
#
#
# Tinley Park
#
#
# Manteno
#
# Waukegan
#
# Mt Prospect
#
# Hickory Hills
#
#
#
# Pleasant Prairie
#
#
#
# Channahon
#
# Frankfort
#
#
#
# Lake in the Hills
#
#
# Shorewood
#
# Glenwood
#
# Round Lake Beach
#
# Flossmoor
#
# Algonquin
#
#
#
# Northlake
#
# Oak Forest
#
# Streamwood
#
# Summit
#
# Blue Island
#
# South Elgin
#
# Hampshire
#
#
#
# Somers
#
# Beach Park
#
# Lake Barrington
#
# Gurnee
#
# Bedford Park
#
#
#
#
#
#
# Mt Pleasant
#
#
# St. John
#
#
#
#
#
#
# Griffith
#
#
# East Troy
#
#
#
#
#
#
#
# Roselle
#
# Hines
#
#
#
# nhom 2 ***********
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Oak Park
#
#
#
#
#
#
# Calumet City
#
#
#
#
#
# Dyer
#
#
#
#
#
#
#
#
# Wheeling
#
#
#
#
#
#
#
#
# Wheaton
#
#
# Maywood
#
#
#
# Countryside
#
#
# Geneva
#
# Glendale Heights
#
#
#
#
#
# Burns Harbor
#
# Hoffman Estates
#
#
# Libertyville
#
# Matteson
#
#
# Niles
#
# Oak Lawn
#
#
#
# Franklin Park
#
#
#
#
#
# Wadsworth
#
#
# River Grove
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Cedar Lake
#
#
#
#
# Carol Stream
#
#
# Glenview
#
#
# Lake Forest
#
# Northbrook
#
#
#
#
#
# Northfield
#
# Harvey
#
#
# Glencoe
#
#
#
# Bourbonnais
#
# Chicago Heights
#
#
#
#
# Lake Bluff
#
# Elmwood Park
#
# Whitewater
#
# St Charles
#
#
#
# Mount Prospect
#
#
# Dixon
#
#
#
#
#
#
#
# Rolling Meadows
#
#
#
#
#
#
#
# Oakbrook Terrace
#
# Ford Heights
#
#
# Oak Brook
#
#
#
#
#
#
# Porter
#
# Rosemont
#
#
#
#
#
#
#
#
# Grayslake
#
# Midlothian
#
#
#
#
#
#
# Lincolnwood
#
# Berwyn
#
# Westchester
#
# Elk Grove Villa
#
# Itasca
#
#
# Vernon Hills
#
#
#
# Whiting
#
# Bristol
#
# Braceville
#
# Carpentersville
#
#
# Delavan
#
#
# Fontana-on-Geneva Lake
#
# Lake Geneva
#
# Glen Ellyn
#
# McHenry
#
# Norridge
#
# Lake Zurich
#
#
#
# Tower Lakes
#
# Rolling Meadow

# %%
List0 = []
for name, k in partition.items():
  if k==0:
    print(name)
    List0.append(name)
Nhom0 = df.query("City in @List0")
Nhom0
# Out:
# Elkhorn
# DeKalb
# Hillside
# Des Plaines
# Schererville
# Evanston
# Markham
# Chicago
# Cicero
# Braidwood
# Lake Villa
# De Motte
# Lombard
# Aurora
# Valparaiso
# Crystal Lake
# Homewood
# West Chicago
# Kenosha
# Naperville
# Lake Station
# Stickney
# Lansing
# Palatine
# Crestwood
# Bradley
# Elgin
# Round Lake Park
# Joliet
# Melrose Park
# Antioch
# Bridgeview
# Dolton
# Freeport
# Hodgkins
# Morris
# Westmont
# Gary
# Bolingbrook
# Hanover Park
# Hammond
# Rockdale
# Hebron
# McCook
# Park Forest
# Morton Grove
# Schriller Park
#     Fuel Type Code          City
# 0              LPG       Elkhorn
# 1              LPG        DeKalb
# 2              LPG      Hillside
# 3              CNG   Des Plaines
# 4              LPG  Schererville
# ..             ...           ...
# 742           ELEC  West Chicago
# 757           ELEC      Westmont
# 760            LPG          Gary
# 792            CNG    Naperville
# 793           ELEC      Hodgkins
#
# [110 rows x 2 columns]

# %%
List1 = []
for name, k in partition.items():
  if k==1:
    print(name)
    List1.append(name)
Nhom1 = df.query("City in @List1")
Nhom1
# Out:
# Kankakee
# Rensselaer
# Woodstock
# Downers Grove
# Lemont
# Batavia
# Great Lakes
# Oswego
# Romeoville
# Homer Glen
# Schaumburg
# Riverside
# North Aurora
# Highland
# Merrillville
# Hobart
# Wheatfield
# Skokie
# Kouts
# Portage
# Chesterton
# Crown Point
# Remington
# Sturtevant
# Gages Lake
# Roselawn
# East Dundee
# Lisle
# Elmhurst
# Lawrence
# University Park
# Robbins
# Volo
# Racine
# Wood Dale
# Palos Hills
# Lakemoor
# Darien
# Lockport
# Lowell
# Schiller Park
# Bloomingdale
# Arlington Heights
# St. Charles
# Elk Grove Village
# South Holland
# Orland Park
# Fair Oaks
# Mokena
# Country Club Hills
# Addison
# Park Ridge
# Villa Park
# Crest Hill
# Fox Lake
# Plainfield
# Yorkville
# Highland Park
# Evergreen Park
# Burlington
# Cary
# Island Lake
# Oak lawn
# Third Lake
# Woodridge
# North Chicago
# Forest Park
# Alsip
# Willowbrook
# West Dundee
# Crete
# New Lenox
# Buffalo Grove
# Burbank
# Bensenville
# Kildeer
# East Chicago
# Montgomery
# Tinley Park
# Manteno
# Waukegan
# Mt Prospect
# Hickory Hills
# Pleasant Prairie
# Channahon
# Frankfort
# Lake in the Hills
# Shorewood
# Glenwood
# Round Lake Beach
# Flossmoor
# Algonquin
# Northlake
# Oak Forest
# Streamwood
# Summit
# Blue Island
# South Elgin
# Hampshire
# Somers
# Beach Park
# Lake Barrington
# Gurnee
# Bedford Park
# Mt Pleasant
# St. John
# Griffith
# East Troy
# Roselle
# Hines
#     Fuel Type Code            City
# 15             LPG        Kankakee
# 17             LPG      Rensselaer
# 19             LPG       Woodstock
# 21             CNG   Downers Grove
# 22             E85          Lemont
# ..             ...             ...
# 816            E85       Fair Oaks
# 817           ELEC        Lakemoor
# 823           ELEC       Shorewood
# 826            E85       East Troy
# 853           ELEC  Evergreen Park
#
# [190 rows x 2 columns]

# %%
List2 = []
for name, k in partition.items():
  if k==2:
    print(name)
    List2.append(name)
Nhom2 = df.query("City in @List2")
Nhom2
# Out:
# Oak Park
# Calumet City
# Dyer
# Wheeling
# Wheaton
# Maywood
# Countryside
# Geneva
# Glendale Heights
# Burns Harbor
# Hoffman Estates
# Libertyville
# Matteson
# Niles
# Oak Lawn
# Franklin Park
# Wadsworth
# River Grove
# Cedar Lake
# Carol Stream
# Glenview
# Lake Forest
# Northbrook
# Northfield
# Harvey
# Glencoe
# Bourbonnais
# Chicago Heights
# Lake Bluff
# Elmwood Park
# Whitewater
# St Charles
# Mount Prospect
# Dixon
# Rolling Meadows
# Oakbrook Terrace
# Ford Heights
# Oak Brook
# Porter
# Rosemont
# Grayslake
# Midlothian
# Lincolnwood
# Berwyn
# Westchester
# Elk Grove Villa
# Itasca
# Vernon Hills
# Whiting
# Bristol
# Braceville
# Carpentersville
# Delavan
# Fontana-on-Geneva Lake
# Lake Geneva
# Glen Ellyn
# McHenry
# Norridge
# Lake Zurich
# Tower Lakes
# Rolling Meadow
#     Fuel Type Code            City
# 64             CNG        Oak Park
# 81             CNG    Calumet City
# 97            ELEC            Dyer
# 111            CNG        Wheeling
# 132            CNG         Wheaton
# ..             ...             ...
# 766           ELEC         McHenry
# 767           ELEC        Norridge
# 772           ELEC     Lake Zurich
# 807           ELEC     Tower Lakes
# 839           ELEC  Rolling Meadow
#
# [65 rows x 2 columns]

# %%
Nhom0.to_excel (r'C:\Users\Mark\Desktop\MXH\finalProject\Excel\Louvain.xlsx', sheet_name='Nhom0', index = False, header=True)

# %%
with pd.ExcelWriter(r'C:\Users\Mark\Desktop\MXH\finalProject\Excel\louvain.xlsx', engine='openpyxl', mode='a') as writer:
    Nhom1.to_excel(writer, sheet_name='Nhom01',index = False, header=True)
    Nhom2.to_excel(writer, sheet_name='Nhom02',index = False, header=True)

# %% [markdown]
# ## Thuật toán Girvan Newman

# %%
def edge_to_remove(G):
  G_dict = nx.edge_betweenness_centrality(G)
  edge = ()
  # trích xuất cạnh có điểm trung tâm giữa cạnh cao nhất
  for key, value in sorted(G_dict.items(), key=lambda item: item[1], reverse = True):
      edge = key
      break
  return edge
def girvan_newman(graph):
	# tìm số lượng các thành phần được kết nối
	sg = nx.connected_components(graph)
	sg_count = nx.number_connected_components(graph)

	while(sg_count == 1):
		graph.remove_edge(edge_to_remove(graph)[0], edge_to_remove(graph)[1])
		sg = nx.connected_components(graph)
		sg_count = nx.number_connected_components(graph)

	return sg
c = girvan_newman(G.copy())
# tìm các nút hình thành cộng đồng
# Tim node
node_groups = []
for i in c:
  node_groups.append(list(i))
print("Phân cụm")
print (node_groups)
#mau 2 cong dong
color_map = []
for node in G:
    if node in node_groups[0]:
        color_map.append('yellow')
    else: 
        color_map.append('red') 
#Ve girvan newman
nx.draw(G, node_color=color_map, with_labels=True)
plt.show()
# Out:
# Phân cụm
# [['Lockport', 'Island Lake', 'Oak Forest', 'Dixon', 'Riverside', 'Hobart', 'Arlington Heights', 'Fontana-on-Geneva Lake', 'Dolton', 'Elgin', 'Woodridge', 'Niles', 'Portage', 'Lemont', 'Channahon', 'Chicago', 'Bradley', 'Pleasant Prairie', 'Crete', 'South Holland', 'Oswego', 'Forest Park', 'Roselle', 'Chicago Heights', 'Grayslake', 'Manteno', 'Libertyville', 'Schriller Park', 'Rolling Meadow', 'Freeport', 'Kouts', 'Elkhorn', 'Evanston', 'Calumet City', 'Norridge', 'Homer Glen', 'Orland Park', 'West Chicago', 'Villa Park', 'Lisle', 'Wheatfield', 'Algonquin', 'Lowell', 'Lake Zurich', 'Palos Hills', 'Whitewater', 'Maywood', 'Naperville', 'Shorewood', 'Mt Pleasant', 'Braidwood', 'Itasca', 'Elmhurst', 'Burbank', 'Bourbonnais', 'Morton Grove', 'Schaumburg', 'Somers', 'Lake Villa', 'Gary', 'North Aurora', 'Schiller Park', 'Fair Oaks', 'Matteson', 'Lake in the Hills', 'Franklin Park', 'Morris', 'Hebron', 'Blue Island', 'Kenosha', 'DeKalb', 'De Motte', 'Lakemoor', 'East Dundee', 'Cedar Lake', 'Crown Point', 'Hoffman Estates', 'Dyer', 'Glenview', 'Elmwood Park', 'Ford Heights', 'Westchester', 'Glenwood', 'Wheeling', 'Montgomery', 'Batavia', 'Oak Lawn', 'Oak Park', 'Glencoe', 'Burns Harbor', 'Lake Barrington', 'Midlothian', 'Elk Grove Villa', 'Tinley Park', 'Buffalo Grove', 'Woodstock', 'Valparaiso', 'Waukegan', 'Oak Brook', 'Porter', 'Highland', 'Bedford Park', 'Hillside', 'Northlake', 'Romeoville', 'Glendale Heights', 'Skokie', 'Carol Stream', 'Racine', 'Northbrook', 'Burlington', 'Markham', 'Schererville', 'Rensselaer', 'Gages Lake', 'Kildeer', 'McCook', 'Griffith', 'Antioch', 'Joliet', 'Bridgeview', 'Elk Grove Village', 'Lansing', 'Great Lakes', 'Lake Bluff', 'Hammond', 'Mount Prospect', 'Remington', 'Plainfield', 'North Chicago', 'Rolling Meadows', 'Des Plaines', 'Third Lake', 'Mt Prospect', 'Gurnee', 'Glen Ellyn', 'Tower Lakes', 'Cicero', 'Crestwood', 'South Elgin', 'Oakbrook Terrace', 'Merrillville', 'Wadsworth', 'Whiting', 'Bensenville', 'Mokena', 'Lake Station', 'McHenry', 'Lawrence', 'Roselawn', 'Chesterton', 'Lake Forest', 'Addison', 'Beach Park', 'Bristol', 'Harvey', 'Volo', 'Bloomingdale', 'Geneva', 'Downers Grove', 'University Park', 'Vernon Hills', 'River Grove', 'Braceville', 'Melrose Park', 'St. John', 'Hines', 'Darien', 'Hampshire', 'Crest Hill', 'Crystal Lake', 'East Troy', 'West Dundee', 'Northfield', 'Lincolnwood', 'Country Club Hills', 'Cary', 'St Charles', 'St. Charles', 'Park Forest', 'Round Lake Park', 'Round Lake Beach', 'Robbins', 'Homewood', 'Wheaton', 'Aurora', 'Berwyn', 'Rockdale', 'Streamwood', 'Alsip', 'Hodgkins', 'Wood Dale', 'Yorkville', 'Evergreen Park', 'Highland Park', 'Oak lawn', 'Frankfort', 'Sturtevant', 'Summit', 'Carpentersville', 'Bolingbrook', 'Palatine', 'Park Ridge', 'Fox Lake', 'Rosemont', 'Willowbrook', 'Flossmoor', 'Delavan', 'Westmont', 'Kankakee', 'New Lenox', 'Hickory Hills', 'Lombard', 'East Chicago', 'Countryside', 'Lake Geneva', 'Hanover Park'], ['Stickney']]

# %% [markdown]
# ## Closeness centrality

# %%
# Độ đo closeness centrality
closeness_centrality = nx.closeness_centrality(G)
for node in sorted(closeness_centrality, key=closeness_centrality.get, reverse=True):
  print(node, closeness_centrality[node])
# Out:
# Des Plaines 1.0
# Chicago 1.0
# Lombard 1.0
# Homewood 1.0
# West Chicago 1.0
# Naperville 1.0
# Joliet 1.0
# Gary 1.0
# Bolingbrook 1.0
# Elkhorn 0.9819004524886877
# DeKalb 0.9819004524886877
# Burbank 0.0
# Rockdale 0.0
# Lake Bluff 0.0
# Elmwood Park 0.0
# Whitewater 0.0
# St Charles 0.0
# Kildeer 0.0
# East Chicago 0.0
# Mount Prospect 0.0
# Dixon 0.0
# Hebron 0.0
# Manteno 0.0
# Mt Prospect 0.0
# Hickory Hills 0.0
# Rolling Meadows 0.0
# McCook 0.0
# Morton Grove 0.0
# Oakbrook Terrace 0.0
# Ford Heights 0.0
# Lake in the Hills 0.0
# Oak Brook 0.0
# Glenwood 0.0
# Round Lake Beach 0.0
# Flossmoor 0.0
# Porter 0.0
# Rosemont 0.0
# Oak Forest 0.0
# Streamwood 0.0
# Summit 0.0
# Blue Island 0.0
# South Elgin 0.0
# Hampshire 0.0
# Grayslake 0.0
# Midlothian 0.0
# Somers 0.0
# Beach Park 0.0
# Lake Barrington 0.0
# Bedford Park 0.0
# Lincolnwood 0.0
# Berwyn 0.0
# Westchester 0.0
# Elk Grove Villa 0.0
# Itasca 0.0
# Mt Pleasant 0.0
# Vernon Hills 0.0
# St. John 0.0
# Schriller Park 0.0
# Whiting 0.0
# Bristol 0.0
# Braceville 0.0
# Carpentersville 0.0
# Delavan 0.0
# Fontana-on-Geneva Lake 0.0
# Lake Geneva 0.0
# Glen Ellyn 0.0
# McHenry 0.0
# Norridge 0.0
# Lake Zurich 0.0
# Roselle 0.0
# Hines 0.0
# Tower Lakes 0.0
# Rolling Meadow 0.0

# %% [markdown]
# ## Girvan Newman

# %%
def edge_to_remove(G):
  G_dict = nx.edge_betweenness_centrality(G)
  edge = ()
  # trích xuất cạnh có điểm trung tâm giữa cạnh cao nhất
  for key, value in sorted(G_dict.items(), key=lambda item: item[1], reverse = True):
      edge = key
      break
  return edge
def girvan_newman(graph):
	# tìm số lượng các thành phần được kết nối
	sg = nx.connected_components(graph)
	sg_count = nx.number_connected_components(graph)

	while(sg_count == 1):
		graph.remove_edge(edge_to_remove(graph)[0], edge_to_remove(graph)[1])
		sg = nx.connected_components(graph)
		sg_count = nx.number_connected_components(graph)

	return sg
c = girvan_newman(G.copy())
# tìm các nút hình thành cộng đồng
# Tim node
node_groups = []
for i in c:
  node_groups.append(list(i))
print("Phân cụm")
print (node_groups)
#mau 2 cong dong
color_map = []
for node in G:
    if node in node_groups[0]:
        color_map.append('yellow')
    else: 
        color_map.append('red') 
#Ve girvan newman
nx.draw(G, node_color=color_map, with_labels=True)
plt.show()
# Out:
# Phân cụm
# [['Woodridge', 'Summit', 'Porter', 'Mount Prospect', 'Willowbrook', 'Gurnee', 'Northbrook', 'Burbank', 'Schriller Park', 'Bedford Park', 'Chicago Heights', 'Hebron', 'Racine', 'Lake in the Hills', 'Roselle', 'East Dundee', 'Fontana-on-Geneva Lake', 'Wheaton', 'Wood Dale', 'Glenwood', 'Crest Hill', 'Romeoville', 'Kildeer', 'Berwyn', 'Woodstock', 'River Grove', 'Hanover Park', 'Schererville', 'Elmwood Park', 'Hampshire', 'Addison', 'Island Lake', 'Roselawn', 'New Lenox', 'Geneva', 'Remington', 'Skokie', 'Rolling Meadows', 'Blue Island', 'Round Lake Park', 'Crown Point', 'Burlington', 'Matteson', 'Evanston', 'Lemont', 'Darien', 'Portage', 'Fair Oaks', 'Lawrence', 'Lisle', 'Algonquin', 'Rolling Meadow', 'Braceville', 'Batavia', 'Melrose Park', 'Braidwood', 'Lakemoor', 'Mt Prospect', 'Highland Park', 'Lake Zurich', 'South Elgin', 'Dixon', 'Pleasant Prairie', 'Oak Brook', 'Country Club Hills', 'Lake Barrington', 'Morris', 'Bristol', 'Lansing', 'Delavan', 'St. Charles', 'Shorewood', 'Rockdale', 'Dyer', 'De Motte', 'Gary', 'Joliet', 'Bolingbrook', 'West Dundee', 'Northfield', 'Whiting', 'Norridge', 'Westmont', 'Homewood', 'Channahon', 'Riverside', 'Streamwood', 'Wheeling', 'Dolton', 'Lombard', 'Carol Stream', 'University Park', 'Glencoe', 'Palatine', 'Grayslake', 'Merrillville', 'South Holland', 'Hodgkins', 'Park Forest', 'Lake Forest', 'Rosemont', 'Frankfort', 'Aurora', 'Northlake', 'Round Lake Beach', 'Kankakee', 'Schiller Park', 'Midlothian', 'Bradley', 'Lake Villa', 'Yorkville', 'Bridgeview', 'Hoffman Estates', 'Beach Park', 'West Chicago', 'Gages Lake', 'East Chicago', 'Kenosha', 'North Chicago', 'Rensselaer', 'Elgin', 'Glen Ellyn', 'Lake Bluff', 'Flossmoor', 'Crystal Lake', 'Crete', 'Hammond', 'Elk Grove Village', 'Cedar Lake', 'Niles', 'Schaumburg', 'Valparaiso', 'Lake Station', 'Antioch', 'Bourbonnais', 'Mt Pleasant', 'Downers Grove', 'Evergreen Park', 'Hickory Hills', 'Westchester', 'Somers', 'Alsip', 'Buffalo Grove', 'Glenview', 'Oakbrook Terrace', 'Third Lake', 'Oak Park', 'Wadsworth', 'Lowell', 'Plainfield', 'Oak Lawn', 'Waukegan', 'Libertyville', 'Palos Hills', 'McCook', 'Volo', 'Villa Park', 'Sturtevant', 'Lake Geneva', 'Orland Park', 'Whitewater', 'Chicago', 'Hobart', 'DeKalb', 'Crestwood', 'Tinley Park', 'Des Plaines', 'North Aurora', 'Arlington Heights', 'Elmhurst', 'Fox Lake', 'Maywood', 'Bloomingdale', 'Tower Lakes', 'Highland', 'Lockport', 'Manteno', 'Elkhorn', 'Carpentersville', 'Griffith', 'Morton Grove', 'Montgomery', 'Great Lakes', 'Naperville', 'Itasca', 'Wheatfield', 'Cary', 'Oak lawn', 'Oak Forest', 'Calumet City', 'Countryside', 'Lincolnwood', 'St. John', 'Franklin Park', 'St Charles', 'McHenry', 'Harvey', 'Glendale Heights', 'Forest Park', 'Elk Grove Villa', 'Burns Harbor', 'Ford Heights', 'Freeport', 'Oswego', 'Homer Glen', 'Chesterton', 'East Troy', 'Bensenville', 'Mokena', 'Kouts', 'Park Ridge', 'Hillside', 'Hines', 'Robbins', 'Cicero', 'Markham', 'Vernon Hills'], ['Stickney']]

# %% [markdown]
# ## Thuật toán Kmeans

# %%
from sklearn import preprocessing
from sklearn.cluster import KMeans
k = preprocessing.LabelEncoder()
df2 = df.copy()

# %%
# Chuyển cột city  thành cột có giá trị số tương ứng
k.fit(df2['City'])
df2['Citynum'] = k.transform(df2['City']) 
df2['Citynum'].drop_duplicates()
# Out:
# 0       56
# 1       43
# 2       90
# 3       45
# 4      179
#       ...
# 772    110
# 776    174
# 804     91
# 807    196
# 839    170
# Name: Citynum, Length: 218, dtype: int32

# %%
# Chuyển cột Fuel Type code thành cột có giá trị số tương ứng
k.fit(df2['Fuel Type Code'])
df2['Fuel Type Code num'] = k.transform(df2['Fuel Type Code']) 
df2['Fuel Type Code num'].drop_duplicates()
# Out:
# 0      5
# 3      1
# 12     2
# 80     3
# 94     0
# 124    4
# Name: Fuel Type Code num, dtype: int32

# %%
# Dự đoán số cụm xuất hiện trong Kmeans bằng phương pháp Elbow
import numpy as np
from sklearn.cluster import KMeans
Sum_of_squared_distances = []
K = range(1,10)
for num_clusters in K :
 kmeans = KMeans(n_clusters=num_clusters)
 kmeans.fit(df2[['Citynum','Fuel Type Code num']])
 Sum_of_squared_distances.append(kmeans.inertia_)
plt.plot(K,Sum_of_squared_distances,'bx-')
plt.xlabel('Values of K') 
plt.ylabel('Sum of squared distances/Inertia') 
plt.title('Elbow Method For Optimal k')
plt.show()
# Out:
# C:\Users\Mark\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(

# %%
#Vẽ thuật toán Kmeans
algorithm = KMeans(n_clusters = 2 ,init='random' )
algorithm.fit(df2[['Citynum','Fuel Type Code num']])
labels2 = algorithm.labels_
centroids2 = algorithm.cluster_centers_ #Gán toạ độ trung tâm cụm
plt.clf()
plt.scatter( x = 'Citynum' ,y = 'Fuel Type Code num' , data = df2[['Citynum','Fuel Type Code num']] , c = labels2 , s = 100 )
plt.scatter(x = centroids2[: , 0] , y =  centroids2[: , 1] , s = 100 , c = 'red' , alpha = 0.5)
plt.ylabel('Fuel Type Code') , plt.xlabel('City')
plt.show()
print('Toạ độ trung tâm cụm: ',centroids2)
# Out:
# Toạ độ trung tâm cụm:  [[162.3908046    2.60344828]
#  [ 52.45549738   2.7434555 ]]

# %%
noteGenre = df2.drop_duplicates(subset='City', keep="last")
print('Số City: ',len(noteGenre[['City','Citynum']]))
print(noteGenre[['City','Citynum']].to_string())
# Out:
# Số City:  218
#                        City  Citynum
# 2                  Hillside       90
# 14                Braidwood       17
# 18                 De Motte       42
# 26                   Oswego      154
# 29               Homer Glen       95
# 31                Riverside      167
# 37               Wheatfield      208
# 39                    Kouts      103
# 60               Gages Lake       70
# 62                 Roselawn      173
# 66              East Dundee       51
# 70               Rensselaer      165
# 75                 Lawrence      114
# 80                  Chicago       31
# 90                  Robbins      168
# 96                     Volo      201
# 97                     Dyer       49
# 109                Lockport      119
# 110                  Lowell      121
# 112              Sturtevant      192
# 116               Remington      164
# 117                 Elkhorn       56
# 118            Merrillville      129
# 125                Stickney      190
# 126                 Lansing      113
# 134                  Skokie      183
# 136                 Maywood      125
# 142             Countryside       35
# 152                  Geneva       72
# 153        Glendale Heights       75
# 159         Round Lake Park      177
# 166            Burns Harbor       23
# 170            Schererville      179
# 172         Hoffman Estates       94
# 176            Libertyville      116
# 178                Matteson      124
# 184                   Niles      140
# 186                Oak Lawn      149
# 190           Downers Grove       48
# 193           Franklin Park       68
# 198           Schiller Park      180
# 202               Wadsworth      202
# 206             River Grove      166
# 207                 Antioch        3
# 209              Bridgeview       18
# 211               Crestwood       37
# 212            Crystal Lake       40
# 213                  Dolton       47
# 215                Freeport       69
# 218            Melrose Park      128
# 219                  Morris      133
# 231                Oak lawn      151
# 233              Third Lake      194
# 235              Cedar Lake       28
# 238             Des Plaines       45
# 244            Hanover Park       84
# 249            Carol Stream       25
# 251                Glenview       76
# 252             Crown Point       39
# 254              Valparaiso      198
# 255           Highland Park       89
# 262             Lake Forest      106
# 263              Northbrook      144
# 266                Oak Park      150
# 275              Schaumburg      178
# 282             Willowbrook      213
# 283             West Dundee      205
# 286                 Kenosha      101
# 302                  Joliet       99
# 307              Northfield      145
# 309                  Harvey       85
# 311                 Wheaton      209
# 312                   Crete       38
# 316                 Glencoe       74
# 318               New Lenox      139
# 321             Great Lakes       79
# 325              Burlington       22
# 326             Bourbonnais       14
# 328         Chicago Heights       32
# 329                 Burbank       21
# 331             St. Charles      188
# 333                   Elgin       53
# 335                  Racine      163
# 336              Park Ridge      158
# 341                Rockdale      169
# 343                  Cicero       33
# 350              Lake Bluff      105
# 352            Elmwood Park       58
# 355              Whitewater      211
# 357              St Charles      187
# 358                 Kildeer      102
# 361            East Chicago       50
# 364                 Lombard      120
# 365          Mount Prospect      135
# 367                   Dixon       46
# 374                  Hebron       86
# 375            Lake Station      108
# 378                 Manteno      122
# 380                Evanston       59
# 383             Mt Prospect      137
# 388           Hickory Hills       87
# 391                Palatine      155
# 392              Chesterton       30
# 394                 Hammond       82
# 396                  Lemont      115
# 400       Elk Grove Village       55
# 401                Wheeling      210
# 402         Rolling Meadows      171
# 404              Crest Hill       36
# 405                  McCook      126
# 407              Lake Villa      109
# 419            Morton Grove      134
# 426        Pleasant Prairie      160
# 432       Arlington Heights        4
# 433                Kankakee      100
# 436        Oakbrook Terrace      152
# 438              Villa Park      200
# 440            Ford Heights       64
# 442                Fox Lake       66
# 448             Bolingbrook       13
# 461               Oak Brook      147
# 464         University Park      197
# 472              Montgomery      132
# 475                Glenwood       77
# 477              Plainfield      159
# 479        Round Lake Beach      176
# 480               Flossmoor       62
# 481             Bensenville        9
# 489                 Markham      123
# 499             Park Forest      157
# 501                  Porter      162
# 505                  DeKalb       43
# 506                 Portage      161
# 510                Rosemont      175
# 519              Oak Forest      148
# 521              Streamwood      191
# 522             Orland Park      153
# 523                  Summit      193
# 526             Blue Island       12
# 529                Waukegan      203
# 530                 Addison        0
# 533             South Elgin      185
# 534                  Aurora        5
# 537              Romeoville      172
# 539               Hampshire       83
# 540               Grayslake       78
# 542                  Hobart       92
# 551                Highland       88
# 553              Midlothian      130
# 555           South Holland      186
# 566                  Somers      184
# 568             Forest Park       65
# 574                 Batavia        6
# 575               Woodstock      216
# 577              Beach Park        7
# 579         Lake Barrington      104
# 581            Bedford Park        8
# 584                Elmhurst       57
# 588             Lincolnwood      117
# 589            Bloomingdale       11
# 590            Calumet City       24
# 591                  Gurnee       81
# 609                  Berwyn       10
# 612             Westchester      206
# 617                 Bradley       16
# 618         Elk Grove Villa       54
# 623               Frankfort       67
# 624             Palos Hills      156
# 625                   Alsip        2
# 627                  Itasca       98
# 637                    Cary       27
# 639       Lake in the Hills      111
# 643            North Aurora      142
# 644               Wood Dale      214
# 645             Island Lake       97
# 646               Channahon       29
# 650             Mt Pleasant      136
# 652               Northlake      146
# 656            Vernon Hills      199
# 669      Country Club Hills       34
# 675                St. John      189
# 677               Yorkville      217
# 680                  Mokena      131
# 682           Buffalo Grove       20
# 685          Schriller Park      181
# 686                   Lisle      118
# 690                 Whiting      212
# 691                 Bristol       19
# 692              Braceville       15
# 699         Carpentersville       26
# 722                Homewood       96
# 739             Tinley Park      195
# 742            West Chicago      204
# 745                 Delavan       44
# 747  Fontana-on-Geneva Lake       63
# 748             Lake Geneva      107
# 750                  Darien       41
# 754              Glen Ellyn       73
# 755               Algonquin        1
# 757                Westmont      207
# 760                    Gary       71
# 766                 McHenry      127
# 767                Norridge      141
# 772             Lake Zurich      110
# 774           North Chicago      143
# 776                 Roselle      174
# 778               Woodridge      215
# 785                Griffith       80
# 792              Naperville      138
# 793                Hodgkins       93
# 804                   Hines       91
# 807             Tower Lakes      196
# 816               Fair Oaks       61
# 817                Lakemoor      112
# 823               Shorewood      182
# 826               East Troy       52
# 839          Rolling Meadow      170
# 853          Evergreen Park       60

# %%
noteGenre = df2.drop_duplicates(subset='Fuel Type Code', keep="last")
print('Số mã loại nhiên liệui: ',len(noteGenre[['Fuel Type Code','Fuel Type Code num']]))
print(noteGenre[['Fuel Type Code','Fuel Type Code num']].to_string())
# Out:
# Số mã loại nhiên liệui:  6
#     Fuel Type Code  Fuel Type Code num
# 488            LNG                   4
# 760            LPG                   5
# 774             BD                   0
# 792            CNG                   1
# 826            E85                   2
# 853           ELEC                   3

# %%
km = KMeans(n_clusters=2)
y_predicted = km.fit_predict(df2[['Fuel Type Code num', 'Citynum' ]])
df2['cluster']= y_predicted
df2
# Out:
#     Fuel Type Code            City  Citynum  Fuel Type Code num  cluster
# 0              LPG         Elkhorn       56                   5        0
# 1              LPG          DeKalb       43                   5        0
# 2              LPG        Hillside       90                   5        0
# 3              CNG     Des Plaines       45                   1        0
# 4              LPG    Schererville      179                   5        1
# ..             ...             ...      ...                 ...      ...
# 817           ELEC        Lakemoor      112                   3        1
# 823           ELEC       Shorewood      182                   3        1
# 826            E85       East Troy       52                   2        0
# 839           ELEC  Rolling Meadow      170                   3        1
# 853           ELEC  Evergreen Park       60                   3        0
#
# [365 rows x 5 columns]

# %%
df2
# Out:
#     Fuel Type Code            City  Citynum  Fuel Type Code num  cluster
# 0              LPG         Elkhorn       56                   5        0
# 1              LPG          DeKalb       43                   5        0
# 2              LPG        Hillside       90                   5        0
# 3              CNG     Des Plaines       45                   1        0
# 4              LPG    Schererville      179                   5        1
# ..             ...             ...      ...                 ...      ...
# 817           ELEC        Lakemoor      112                   3        1
# 823           ELEC       Shorewood      182                   3        1
# 826            E85       East Troy       52                   2        0
# 839           ELEC  Rolling Meadow      170                   3        1
# 853           ELEC  Evergreen Park       60                   3        0
#
# [365 rows x 5 columns]
